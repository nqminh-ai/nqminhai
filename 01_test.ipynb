# %%
import pandas as pd
import xgboost as xgb
print("VS Code + Jupyter sẵn sàng!")
print(f"Pandas version: {pd.__version__}")
print(f"XGBoost version: {xgb.__version__}")
# Out:
# VS Code + Jupyter sẵn sàng!
# Pandas version: 2.3.3
# XGBoost version: 3.2.0
